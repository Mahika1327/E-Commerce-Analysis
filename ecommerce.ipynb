# %%
# !pip install streamlit pandas plotly openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
os.listdir()
# Out:
# ['.arduinoIDE',
#  '.bash_history',
#  '.config',
#  '.copilot',
#  '.gh.json',
#  '.gitconfig',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.lesshst',
#  '.matplotlib',
#  '.neo-browser',
#  '.packettracer',
#  '.python_history',
#  '.redhat',
#  '.VirtualBox',
#  '.vscode',
#  '12400378_CA1.ipynb',
#  'adieu',
#  'AppData',
#  'Application Data',
#  'ayo',
#  'basics',
#  'beginning',
#  'Cisco Packet Tracer 8.2.2',
#  'coffeeShop',
#  'Contacts',
#  'Cookies',
#  'data.csv',
#  'dataframe.csv',
#  'datasetimport.ipynb',
#  'Documents',
#  'Downloads',
#  'ecommerce.ipynb',
#  'f1',
#  'f11',
#  'f12',
#  'f13',
#  'f6',
#  'f7',
#  'Favorites',
#  'File',
#  'filesum',
#  'firstfile',
#  'g.html',
#  'hello.html',
#  'hello.py',
#  'IntelGraphicsProfiles',
#  'Job_data.csv',
#  'Links',
#  'Local Settings',
#  'Microsoft',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'np_aaray.npy',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
# ...

# %%
import pandas as pd
df = pd.read_csv("python_dataset.csv")
df.head()
# Out:
#    order_id  order_date  product_id product_category   price  \
# 0         1  13-04-2022        2637            Books  128.75
# 1         2  12-03-2023        2300          Fashion  302.60
# 2         3  28-09-2022        3670           Sports  495.80
# 3         4  17-04-2022        2522            Books  371.95
# 4         5  13-03-2022        1717           Beauty  201.68
#
#    discount_percent  quantity_sold customer_region payment_method  rating  \
# 0                10              4   North America            UPI     3.5
# 1                20              5            Asia    Credit Card     3.7
# 2                20              2          Europe            UPI     4.4
# 3                15              4     Middle East            UPI     5.0
# 4                 0              4     Middle East            UPI     4.6
#
#    review_count  discounted_price  total_revenue  profit
# 0           443            115.88         463.52  23.176
# ...
